# %%
# ==============================================================
# 1. Import libraries
# ==============================================================

import numpy as np
import os
import networkx as nx
from numpy import genfromtxt
from gtda.graphs import GraphGeodesicDistance
from gtda.homology import FlagserPersistence
from gtda.diagrams import PersistenceLandscape
from gtda.plotting import plot_diagram
from IPython.display import display

# ==============================================================
# 2. Define paths 
# ==============================================================

input_dir = "../data/GRN_adjacency_matrices"       # folder containing GRN adjacency matrices
output_dir = "../output/PH"           # folder to store PH 

# ==============================================================
# 3. Define function to compute PH
# ==============================================================

def compute_persistence(adjacency_matrix):
    """Computes persistent homology from adjacency matrix."""
    G = nx.convert.to_networkx_graph(adjacency_matrix)
    adj = nx.adjacency_matrix(G)

    X_ggd = GraphGeodesicDistance(directed=False, unweighted=False).fit_transform([adj])
    PH = FlagserPersistence(directed=False).fit_transform(X_ggd)

    return PH[0]  

# ==============================================================
# 4. Batch run over all matrices
# ==============================================================

files = sorted([f for f in os.listdir(input_dir) if f.endswith(".csv")])
print(f"Found {len(files)} input matrices.")

for i, fname in enumerate(files):
    print(f"\nProcessing file {i+1}/{len(files)}: {fname}")

    # Read matrix
    mat = genfromtxt(os.path.join(input_dir, fname), delimiter=',')
    
    # Compute PH
    PH = compute_persistence(mat)

    # Save PH output
    out_path = os.path.join(output_dir, fname.replace(".csv", "_PH.csv"))
    np.savetxt(out_path, PH, delimiter=',', fmt="%.4f")

    print(f"Saved PH results at: {out_path}")
# Out:
# Found 17 input matrices.
#
# Processing file 1/17: Asymptomaticadjmatrix11.csv
# Saved PH results at: ../output/PH\Asymptomaticadjmatrix11_PH.csv
#
# Processing file 2/17: Asymptomaticadjmatrix14.csv
# Saved PH results at: ../output/PH\Asymptomaticadjmatrix14_PH.csv
#
# Processing file 3/17: Asymptomaticadjmatrix16.csv
# Saved PH results at: ../output/PH\Asymptomaticadjmatrix16_PH.csv
#
# Processing file 4/17: Asymptomaticadjmatrix17.csv
# Saved PH results at: ../output/PH\Asymptomaticadjmatrix17_PH.csv
#
# Processing file 5/17: Asymptomaticadjmatrix2.csv
# Saved PH results at: ../output/PH\Asymptomaticadjmatrix2_PH.csv
#
# Processing file 6/17: Asymptomaticadjmatrix3.csv
# Saved PH results at: ../output/PH\Asymptomaticadjmatrix3_PH.csv
#
# Processing file 7/17: Asymptomaticadjmatrix4.csv
# Saved PH results at: ../output/PH\Asymptomaticadjmatrix4_PH.csv
#
# Processing file 8/17: Asymptomaticadjmatrix9.csv
# Saved PH results at: ../output/PH\Asymptomaticadjmatrix9_PH.csv
#
# Processing file 9/17: Symptomaticadjmatrix1.csv
# Saved PH results at: ../output/PH\Symptomaticadjmatrix1_PH.csv
#
# Processing file 10/17: Symptomaticadjmatrix10.csv
# Saved PH results at: ../output/PH\Symptomaticadjmatrix10_PH.csv
#
# Processing file 11/17: Symptomaticadjmatrix12.csv
# Saved PH results at: ../output/PH\Symptomaticadjmatrix12_PH.csv
#
# Processing file 12/17: Symptomaticadjmatrix13.csv
# Saved PH results at: ../output/PH\Symptomaticadjmatrix13_PH.csv
#
# Processing file 13/17: Symptomaticadjmatrix15.csv
# Saved PH results at: ../output/PH\Symptomaticadjmatrix15_PH.csv
#
# Processing file 14/17: Symptomaticadjmatrix5.csv
# Saved PH results at: ../output/PH\Symptomaticadjmatrix5_PH.csv
#
# Processing file 15/17: Symptomaticadjmatrix6.csv
# Saved PH results at: ../output/PH\Symptomaticadjmatrix6_PH.csv
#
# Processing file 16/17: Symptomaticadjmatrix7.csv
# Saved PH results at: ../output/PH\Symptomaticadjmatrix7_PH.csv
#
# Processing file 17/17: Symptomaticadjmatrix8.csv
# Saved PH results at: ../output/PH\Symptomaticadjmatrix8_PH.csv
